# %%
import numpy as np 

def emittance_rms(q,p):
    q = np.array(q)
    p = np.array(p)

    mean_q = np.mean(q)
    mean_p = np.mean(p)

    var_qq = np.mean((q-mean_q)**2)
    var_pp = np.mean((p-mean_p)**2)
    var_qp = np.mean((q-mean_q)*(p-mean_p))

    emittance = np.sqrt(var_qq * var_pp - var_qp**2)

    return emittance

# %%
import pandas as pd
import re

archive = 'stats.txt'

# Leer encabezado y datos
with open(archive, 'r', encoding='utf-8') as f:
    rows = f.readlines()

headers = [col.strip() for col in rows[7].strip().split(',')]
data = pd.read_csv(archive, skiprows=8, names=headers)

target_x = 566
tolerance = 10

# Encuentra todas las columnas de posición x, y, z
qx_cols = [col for col in data.columns if col.startswith("qx")]
qy_cols = [col for col in data.columns if col.startswith("qy")]
qz_cols = [col for col in data.columns if col.startswith("qz")]
py_cols = [col for col in data.columns if col.startswith("cpt.ppy")]
pz_cols = [col for col in data.columns if col.startswith("cpt.ppz")]

# Extraer el tiempo de cada columna para mapear qx-qy-qz
def get_time(col):
    return col.split("t=")[-1]

# Diccionarios para relacionar columnas qx <-> qy, qz, py, pz por tiempo
time_to_qx = {get_time(col): col for col in qx_cols}
time_to_qy = {get_time(col): col for col in qy_cols}
time_to_qz = {get_time(col): col for col in qz_cols}
time_to_py = {get_time(col): col for col in py_cols}
time_to_pz = {get_time(col): col for col in pz_cols}

# Intersección de tiempos disponibles en qx, qy y qz
common_times = set(time_to_qx) & set(time_to_qy) & set(time_to_qz) & set(time_to_py) & set(time_to_pz)

# Lista para guardar los resultados
results = []

# Iteramos sobre cada partícula
for idx, row in data.iterrows():
    found = False
    for t in sorted(common_times, key=lambda x: float(x)):
        qx_val = row[time_to_qx[t]]
        if target_x - tolerance <= qx_val <= target_x + tolerance:
            qy_val = row[time_to_qy[t]]
            qz_val = row[time_to_qz[t]]
            py_val = row[time_to_py[t]]
            pz_val = row[time_to_pz[t]]
            results.append({
                "particula": idx,
                "tiempo": float(t),
                "qx": qx_val,
                "qy": qy_val,
                "qz": qz_val,
                "py": py_val,
                "pz": pz_val
            })
            found = True
            break  # solo queremos el primer instante que cumple
    if not found:
        continue  # si no pasó por el rango, no se guarda

# Convertimos a DataFrame
df_results = pd.DataFrame(results)

# Mostramos cuántas partículas se encontraron
print(f"x={target_x} ± {tolerance} mm planoa igaro duten partikulak: {len(df_results)}")
print(df_results.head())
df_results.to_csv(f"stats_x{target_x}mm.csv", index=False)
# Out:
# x=566 ± 10 mm planoa igaro duten partikulak: 20000
#    particula  tiempo          qx        qy        qz        py        pz
# 0          0  288.99  566.525369 -2.698875 -5.216711 -0.006069 -0.004063
# 1          1  288.99  569.857182  0.000557  6.948885 -0.000573  0.007501
# 2          2  267.32  557.217309  7.016970  1.395241  0.011186  0.002317
# 3          3  274.54  568.730067  3.569878 -7.914891  0.005051 -0.011022
# 4          4  303.44  568.996283 -4.722815  3.882641 -0.006513  0.003233

# %%
import matplotlib.pyplot as plt

# Suponiendo que df_resultados contiene las columnas 'qy', 'qz' y 'particula'
plt.figure(figsize=(8, 8))
plt.scatter(df_results['qy'], df_results['qz'], s=5, alpha=0.7)

plt.title(f"Distribución transversal de partículas en x={target_x}±{tolerance} mm")
plt.xlabel("qy (mm)")
plt.ylabel("qz (mm)")
plt.grid(True)
plt.axis('equal')  # Para que los ejes tengan la misma escala

plt.tight_layout()
plt.show()

# %%
y_emittance = emittance_rms(df_results['qy'], df_results['py'])
z_emittance = emittance_rms(df_results['qz'], df_results['pz'])

print("Emitantzia-y:", y_emittance, " (mm rad)")
print("Emitantzia-z:", z_emittance, " (mm rad)")
# Out:
# Emitantzia-y: 0.00933546405119897  (mm rad)
# Emitantzia-z: 0.009054810185909139  (mm rad)

# %%
plt.figure(figsize=(8, 8))
plt.scatter(df_results['qy'], df_results['py'], s=5, alpha=0.7)

plt.title(f"Fase espazioa y-y' (x={target_x}±{tolerance} mm)")
plt.xlabel("qy (mm)")
plt.ylabel("py (rad)")
plt.grid(True)
plt.xlim(-15,15)
plt.ylim(-0.03,0.03)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.scatter(df_results['qz'], df_results['pz'], s=5, alpha=0.7)

plt.title(f"Fase espazioa z-z' (x={target_x}±{tolerance} mm)")
plt.xlabel("qz (mm)")
plt.ylabel("pz (rad)")
plt.grid(True)
plt.xlim(-15,15)
plt.ylim(-0.03,0.03)

plt.tight_layout()
plt.show()
