# %%
from GlobalModel_Class import GlobalModel
import Reactions as R
import matplotlib.pyplot as plt
import numpy as np

me=9.11e-31
mp=1.67e-27
q=1.6e-19

# %%
gm=GlobalModel(R.reactions1)

# %% [markdown]
# ### Reacciones

# %%
# %matplotlib inline
figure=plt.figure(figsize=(12,5))
elog=np.logspace(-0.5,3)
for i in range (len(R.reactions1)):
    r=R.reactions2[i]
    if r[1]!='surface':
        plt.plot(elog,r[5](elog),label=r[0])
plt.yscale('log')
plt.xscale('log')
plt.ylim(1e-10,1e-6)
plt.xlabel('T(eV)')
plt.ylabel('$<\sigma v>$ (cm$^{3}$/s)')
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.tight_layout()
plt.savefig('Figures\Cs.pdf')

# %% [markdown]
# ### Graficas 1D

# %%
n,nH,n1,n2,n3,ne,e=gm.Find_solution_n_sweep(3e6,5e13,3e15,30)
plt.plot(n,n1,color='blue',label='H+')
plt.plot(n,n2,color='red',label='H2+')
plt.plot(n,n3,color='green',label='H3+')
plt.legend()
plt.ylabel('$n$ (cm$^{-3}$)')
plt.xlabel('$n_0$ (cm$^{-3}$)')
# Out:
# Text(0.5, 0, '$n_0$ (cm$^{-3}$)')

# %%
p,nH,n1,n2,n3,ne,e=gm.Find_solution_p_sweep(1e15,3e5,4e6,30)
plt.plot(p,n1,color='blue',label='H+')
plt.plot(p,n2,color='red',label='H2+')
plt.plot(p,n3,color='green',label='H3+')
plt.ylabel('$n$ (cm$^{-3}$)')
plt.xlabel('$P_\mu$ (W/m$^{3}$)')
plt.legend()

# %%
nmin,nmax=1e14,3e15
pmin,pmax=1e5,5e6
N=50
p01,p02,p03=5e5,1e6,5e6
n01,n02,n03=1e14,5e14,1e15
'''
_______________________________________________________________________
'''
fig,ax=plt.subplots(1,2,figsize=(10,3))
n,nH,n1,n2,n3,ne,e=gm.Find_solution_n_sweep(p01,nmin,nmax,N)
ax[0].plot(n,e,label='P$_\mu$=5e5 W/m$^{3}$')
n,nH,n1,n2,n3,ne,e=gm.Find_solution_n_sweep(p02,nmin,nmax,N)
ax[0].plot(n,e,label='P$_\mu$=1e6 W/m$^{3}$')
n,nH,n1,n2,n3,ne,e=gm.Find_solution_n_sweep(p03,nmin,nmax,N)
ax[0].plot(n,e,label='$P_\mu$=1e7 W/m$^{3}$')
p,nH,n1,n2,n3,ne,e=gm.Find_solution_p_sweep(n01,pmin,pmax,N)
ax[1].plot(p,e,label='$n_0$=1e14 cm$^{-3}$')
p,nH,n1,n2,n3,ne,e=gm.Find_solution_p_sweep(n02,pmin,pmax,N)
ax[1].plot(p,e,label='$n_0$=5e14 cm$^{-3}$')
p,nH,n1,n2,n3,ne,e=gm.Find_solution_p_sweep(n03,pmin,pmax,N)
ax[1].plot(p,e,label='$n_0$=1e15 cm$^{-3}$')

ax[0].set_ylabel('$T_e$ (eV)')
ax[0].set_xlabel('$n_0$ (cm$^{-3}$)')
ax[1].set_ylabel('$T_e$ (eV)')
ax[1].set_xlabel('$P_\mu$ (W/m$^{3}$)')
ax[0].legend()
ax[1].legend()
plt.tight_layout()
plt.savefig('Figures\Te_lines.pdf')

# %%
nmin,nmax=1e14,3e15
pmin,pmax=1e5,5e6
N=50
p01,p02,p03=5e5,1e6,5e6
n01,n02,n03=1e14,5e14,1e15
'''
__________________________________________________________________
'''
fig,ax=plt.subplots(1,2,figsize=(10,3))
n,nH,n1,n2,n3,ne,e=gm.Find_solution_n_sweep(p01,nmin,nmax,N)
ax[0].plot(n,ne,label='$P_\mu$=5e5 W/m$^{3}$')
n,nH,n1,n2,n3,ne,e=gm.Find_solution_n_sweep(p02,nmin,nmax,N)
ax[0].plot(n,ne,label='$P_\mu$=1e6 W/m$^{3}$')
n,nH,n1,n2,n3,ne,e=gm.Find_solution_n_sweep(p03,nmin,nmax,N)
ax[0].plot(n,ne,label='$P_\mu$=1e7 W/m$^{3}$')
p,nH,n1,n2,n3,ne,e=gm.Find_solution_p_sweep(n01,pmin,pmax,N)
ax[1].plot(p,ne,label='$n_0$=1e14 cm$^{-3}$')
p,nH,n1,n2,n3,ne,e=gm.Find_solution_p_sweep(n02,pmin,pmax,N)
ax[1].plot(p,ne,label='$n_0$=5e14 cm$^{-3}$')
p,nH,n1,n2,n3,ne,e=gm.Find_solution_p_sweep(n03,pmin,pmax,N)
ax[1].plot(p,ne,label='$n_0$=1e15 cm$^{-3}$')

ax[0].set_ylabel('$n_e$ (eV)')
ax[0].set_xlabel('$n_0$ (cm$^{-3}$)')
ax[1].set_ylabel('$n_e$ (eV)')
ax[1].set_xlabel('$P_\mu$ (W/m$^{3}$)')
ax[0].legend()
ax[1].legend()
plt.tight_layout()
plt.savefig('Figures/Ne_lines.pdf')

# %%
p0=3e6
n0=2e15
pmin,pmax=1e5,5e6
nmin,nmax=1e14,3e15
N=50
'''
_________________________________________________________________
'''
fig,ax=plt.subplots(1,2,figsize=(10,3))
n,nH,n1,n2,n3,ne,e=gm.Find_solution_n_sweep(p0,nmin,nmax,N)
ax[0].plot(n,n1,color='blue',label='$n_{H^+}$')
ax[0].plot(n,n2,color='red',label='$n_{H_2^+}$')
ax[0].plot(n,n3,color='green',label='$n_{H_3^+}$')
p,nH,n1,n2,n3,ne,e=gm.Find_solution_p_sweep(n0,pmin,pmax,N)
ax[1].plot(p,n1,color='blue',label='$n_{H^+}$')
ax[1].plot(p,n2,color='red',label='$n_{H_2^+}$')
ax[1].plot(p,n3,color='green',label='$n_{H_3^+}$')

ax[0].set_ylabel('$n_e$ (eV)')
ax[0].set_xlabel('$n_0$ (cm$^{-3}$)')
ax[1].set_ylabel('$n_e$ (eV)')
ax[1].set_xlabel('$P_\mu$ (W/m$^{3}$)')
ax[0].legend()
ax[1].legend()
plt.tight_layout()
plt.savefig('Figures\species_lines.pdf')

# %% [markdown]
# ### Solución 2D

# %%
'''No he definido esta función dentro de la clase GlobalModel, por que necesita
mucho tiempo en calcular la solución 2D. Por eso, calculo el resultado
con gm.Find_solution_2D_sweep y con la función Zonas() represento los mayoritarios utilizando la
solución anterior'''
def zonas(n1array,n2array,n3array):
    N_mayoritario=np.empty((n1array.shape[0],n1array.shape[1]))
    N_mayoritario[:]=np.nan
    limites=np.empty((n1array.shape[0],n1array.shape[1]))
    limites[:]=np.nan
    for i in range (n1array.shape[0]):
        for j in range (n1array.shape[1]):
            if (n1array[i,j]>n2array[i,j])&(n1array[i,j]>n3array[i,j]):
                N_mayoritario[i,j]=1
            if (n2array[i,j]>n1array[i,j])&(n2array[i,j]>n3array[i,j]):
                N_mayoritario[i,j]=2
            if (n3array[i,j]>n2array[i,j])&(n3array[i,j]>n1array[i,j]):
                N_mayoritario[i,j]=3
    for i in range(N_mayoritario.shape[0]-1):
        for j in range(N_mayoritario.shape[1]-1):
            if (N_mayoritario[i,j]!=N_mayoritario[i+1,j])|(N_mayoritario[i,j]!=N_mayoritario[i,j+1]):
                limites[i,j]=1
    return [N_mayoritario,limites]

# %%
pmin,pmax=1e5,5e6
nmin,nmax=1e14,3e15
Nn,Np=80,80
nn,pp,nH2,nH,n1,n2,n3,ne,e=gm.Find_solution_2D_sweep(pmin,pmax,nmin,nmax,Np,Nn)

# %%
# %matplotlib widget
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
mpl.rcParams['legend.fontsize'] = 10

#Species
fig = plt.figure(figsize=(6,5))
ax = fig.gca(projection='3d')
ax.scatter(nn,pp,n1,alpha=0.1,s=2,color='blue',label='H+')
ax.scatter(nn,pp,n2,alpha=0.1,s=2,color='red',label='H2+')
ax.scatter(nn,pp,n3,alpha=0.1,s=2,color='green',label='H3+')
plt.xlabel('$n_0$ (cm$^{-3}$)')
plt.ylabel('$P_\mu$ (W/m$^{3}$)')
plt.savefig('Figures/3D_species.pdf')

#Species
fig = plt.figure()
ax = fig.gca(projection='3d')
#ax.scatter(nn,pp,nH2,alpha=0.5,label='H2')
ax.scatter(nn,pp,nH,s=2,alpha=0.5,label='H')
plt.xlabel('$n_0$ (cm$^{-3}$)')
plt.ylabel('$P_\mu$ (W/m$^{-3}$)')
ax.legend()
plt.tight_layout()

#T_e
mpl.rcParams['legend.fontsize'] = 10
fig = plt.figure(figsize=(6,5))
ax = fig.gca(projection='3d')
ax.scatter(nn,pp,e,alpha=0.5,s=2,label='$T_e$ (eV)')
plt.xlabel('$n_0$ (cm$^{-3}$)')
plt.ylabel('$P_\mu$ (W/m$^{3}$)')
plt.tight_layout()
plt.legend()
plt.savefig('Figures/3D_Te.pdf')

#n_e
mpl.rcParams['legend.fontsize'] = 10
fig = plt.figure(figsize=(6,5))
ax = fig.gca(projection='3d')
ax.scatter(nn,pp,n1+n2+n3,alpha=0.5,s=2,label='$n_e$ (cm$^{-3}$)')
plt.xlabel('$n_0$ (cm$^{-3}$)')
plt.ylabel('$P_\mu$ (W/m$^{3}$)')
plt.tight_layout()
plt.legend()
plt.savefig('Figures/3D_ne.pdf')

#Dissociation degree
mpl.rcParams['legend.fontsize'] = 10
fig = plt.figure(figsize=(6,5))
ax = fig.gca(projection='3d')
ax.scatter(nn,pp,nH/(nH+2*nH2),alpha=0.5,s=2,label='Dissociation_degree')
plt.xlabel('$n_0$ (cm$^{-3}$)')
plt.ylabel('$P_\mu$ (W/m$^{-3}$)')
ax.legend()
plt.tight_layout()
plt.savefig('Figures/3D_dissociation.pdf')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import matplotlib.colors as colors
colorsList = ['blue','red','green']
CustomCmap = colors.ListedColormap(colorsList)
bounds = np.array([0.5,1.5,2.5,3.5])
norm = colors.BoundaryNorm(boundaries=bounds, ncolors=4)

N_mayoritario,limites=zonas(n1,n2,n3)

plt.figure(figsize=(8,4))
plt.scatter(nn.flatten(),pp.flatten(),c=N_mayoritario.flatten().T,cmap=CustomCmap,norm=norm)
plt.xlim([nmin,nmax])
plt.ylim([pmin,pmax])
plt.xlabel('$n_0$ (cm$^{-3}$)')
plt.ylabel('$P_\mu$ (W/m$^{-3}$)')
plt.savefig('Figures/Predominant_map.pdf')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4349             try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4350                 colors = mcolors.to_rgba_array(c)
#    4351             except (TypeError, ValueError) as err:
#
# ~\Anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba_array(c, alpha)
#     384     else:
# --> 385         rgba = np.array([to_rgba(cc) for cc in c])
#     386
#
# ~\Anaconda3\lib\site-packages\matplotlib\colors.py in <listcomp>(.0)
#     384     else:
# --> 385         rgba = np.array([to_rgba(cc) for cc in c])
#     386
#
# ~\Anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     205     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# ...

# %% [markdown]
# ### Contribución de cada reacción

# %%
n0=1e15
pmin,pmax=3e5,3e6
p0=3e6
nmin,nmax=1e14,2e15
N=30
'''
_________________________________________________________________________________
'''
# %matplotlib inline
fig,ax=plt.subplots(1,2,figsize=(10,3))
ps,names0,values0=gm.Contributions_p_sweep([mp,0],n0,pmin,pmax,N)
for i in range (values0[0,:].size):
    ax[1].plot(ps,abs(values0[:,i]),label=names0[i])
ns,names0,values0=gm.Contributions_n_sweep([mp,0],p0,nmin,nmax,N)
for i in range (values0[0,:].size):
    ax[0].plot(ns,abs(values0[:,i]),label=names0[i])
ax[1].set_xlabel('P$_\mu$(W/m$^3$)')
ax[1].set_ylabel('$n_in_j$|<$\sigma$v>|')
ax[0].set_xlabel('$n_0$ (cm$^{-3}$)')
ax[0].set_ylabel('$n_in_j$|<$\sigma$v>|')
ax[1].set_yscale('log')
ax[0].set_yscale('log')
ax[1].legend(bbox_to_anchor=(1.04,1), loc="upper left")
#fig.suptitle('Reactions involving H', fontsize=16)
plt.tight_layout()
plt.savefig('Figures/Contributions_h.pdf')

fig,ax=plt.subplots(1,2,figsize=(10,3))
ps,names0,values0=gm.Contributions_p_sweep([mp,1],n0,pmin,pmax,N)
for i in range (values0[0,:].size):
    ax[1].plot(ps,abs(values0[:,i]),label=names0[i])
ns,names0,values0=gm.Contributions_n_sweep([mp,1],p0,nmin,nmax,N)
for i in range (values0[0,:].size):
    ax[0].plot(ns,abs(values0[:,i]),label=names0[i])
ax[1].set_xlabel('P$_\mu$(W/m$^3$)')
ax[1].set_ylabel('$n_in_j$|<$\sigma$v>|')
ax[0].set_xlabel('$n_0$ (cm$^{-3}$)')
ax[0].set_ylabel('$n_in_j$|<$\sigma$v>|')
ax[1].set_yscale('log')
ax[0].set_yscale('log')
ax[1].legend(bbox_to_anchor=(1.04,1), loc="upper left")
#fig.suptitle('Reactions involving H+', fontsize=16)
plt.tight_layout()
plt.savefig('Figures/Contributions_h+.pdf')


fig,ax=plt.subplots(1,2,figsize=(10,3))
ps,names0,values0=gm.Contributions_p_sweep([2*mp,1],n0,pmin,pmax,N)
for i in range (values0[0,:].size):
    ax[1].plot(ps,abs(values0[:,i]),label=names0[i])
ns,names0,values0=gm.Contributions_n_sweep([2*mp,1],p0,nmin,nmax,N)
for i in range (values0[0,:].size):
    ax[0].plot(ns,abs(values0[:,i]),label=names0[i])
ax[1].set_xlabel('P$_\mu$(W/m$^3$)')
ax[1].set_ylabel('$n_in_j$|<$\sigma$v>|')
ax[0].set_xlabel('$n_0$ (cm$^{-3}$)')
ax[0].set_ylabel('$n_in_j$|<$\sigma$v>|')
ax[1].set_yscale('log')
ax[0].set_yscale('log')
ax[1].legend(bbox_to_anchor=(1.04,1), loc="upper left")
#fig.suptitle('Reactions involving H2+', fontsize=16)
plt.tight_layout()
plt.savefig('Figures/Contributions_h2+.pdf')


fig,ax=plt.subplots(1,2,figsize=(10,3))
ps,names0,values0=gm.Contributions_p_sweep([3*mp,1],n0,pmin,pmax,N)
for i in range (values0[0,:].size):
    ax[1].plot(ps,abs(values0[:,i]),label=names0[i])
ns,names0,values0=gm.Contributions_n_sweep([3*mp,1],p0,nmin,nmax,N)
for i in range (values0[0,:].size):
    ax[0].plot(ns,abs(values0[:,i]),label=names0[i])
ax[1].set_xlabel('P$_\mu$(W/m$^3$)')
ax[1].set_ylabel('$n_in_j$|<$\sigma$v>|')
ax[0].set_xlabel('$n_0$ (cm$^{-3}$)')
ax[0].set_ylabel('$n_in_j$|<$\sigma$v>|')
ax[1].set_yscale('log')
ax[0].set_yscale('log')
ax[1].legend(bbox_to_anchor=(1.04,1), loc="upper left")
#fig.suptitle('Reactions involving H3+', fontsize=16)
plt.tight_layout()
plt.savefig('Figures/Contributions_h3+.pdf')

# %%
values0[0]
# Out:
# array([1.36422126e+03, 1.19867067e+05, 1.92072319e+02, 3.59472515e+04,
#        6.10645886e+00, 2.68332526e+03, 9.91733201e-01, 1.34836129e+03,
#        1.66528444e+01, 2.05251834e+01, 4.93329877e-01, 1.37464386e+04,
#        1.33056387e+03, 7.62474212e+00])

# %%
pmin,pmax=3e5,4e6
nmin,nmax=1e14,3e15
Np,Nn=60,60

'''
______________________________________________________________________________________
'''
# %matplotlib widget
from mpl_toolkits.mplot3d import Axes3D
import matplotlib as mpl
mpl.rcParams['legend.fontsize'] = 10

nn,pp,names0,values0=gm.Contributions_2D_sweep([mp,0],pmin,pmax,nmin,nmax,Np,Nn)
fig = plt.figure()
ax = fig.gca(projection='3d')
for i in range (values0[0,0,:].size):
    ax.scatter(nn,pp,np.log10(abs(values0[:,:,i])),label=names0[i])
plt.xlabel('n$_0$(cm$^{-3}$)')
plt.ylabel('p$_\mu$(W/m$^{3}$)')
plt.legend()
plt.title('H generation')

nn,pp,names1,values1=gm.Contributions_2D_sweep([mp,1],pmin,pmax,nmin,nmax,Np,Nn)
fig = plt.figure()
ax = fig.gca(projection='3d')
for i in range (values1[0,0,:].size):
    ax.scatter(nn,pp,np.log10(abs(values1[:,:,i])),label=names1[i])
plt.xlabel('n$_0$(cm$^{-3}$)')
plt.ylabel('p$_\mu$(W/m$^{3}$)')
plt.legend()
plt.title('H+ generation')

nn,pp,names2,values2=gm.Contributions_2D_sweep([2*mp,1],pmin,pmax,nmin,nmax,Np,Nn)
fig = plt.figure()
ax = fig.gca(projection='3d')
for i in range (values2[0,0,:].size):
    ax.scatter(nn,pp,np.log10(abs(values2[:,:,i])),label=names2[i])
plt.xlabel('n$_0$(cm$^{-3}$)')
plt.ylabel('p$_\mu$(W/m$^{3}$)')
plt.legend()
plt.title('H2+ generation')

nn,pp,names3,values3=gm.Contributions_2D_sweep([3*mp,1],pmin,pmax,nmin,nmax,Np,Nn)
fig = plt.figure()
ax = fig.gca(projection='3d')
for i in range (values3[0,0,:].size):
    ax.scatter(nn,pp,np.log10(abs(values3[:,:,i])),label=names3[i])
plt.xlabel('n$_0$(cm$^{-3}$)')
plt.ylabel('p$_\mu$(W/m$^{3}$)')
plt.legend()
plt.title('H3+ generation')
# Out:
# Text(0.5, 0.92, 'H3+ generation')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Absorción de energía

# %%
p0=5e5
nmin,nmax=1e14,1e15
n0=1e14
pmin,pmax=1e5,5e5
N=30
'''
___________________________________________________________________________
'''
fig,ax=plt.subplots(1,2,figsize=(10,4))
ns,names0,values0=gm.Absortion_n_sweep(p0,nmin,nmax,N)
ps,names1,values1=gm.Absortion_p_sweep(n0,pmin,pmax,N)
for i in range(len(names0)):
    ax[1].plot(ns,values1[:,i],label=names0[i])
for i in range(len(names0)):
    ax[0].plot(ps,values0[:,i],label=names0[i])
ax[0].set_xlabel('P$_\mu$(W/m$^3$)')
ax[1].set_ylabel('P$_{absorbed}$(W/m$^3$)')
ax[1].set_xlabel('$n_0$ (cm$^{-3}$)')
ax[0].set_ylabel('P$_{absorbed}$(W/m$^3$)')
ax[1].set_yscale('log')
ax[0].set_yscale('log')
ax[1].legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.tight_layout()
plt.savefig('Figures/Power_absortion.pdf')

# %% [markdown]
# ### Sensibilidad a diferentes parametros

# %% [markdown]
# Sensibilidad a gamma

# %%
gm1=GlobalModel(R.reactions1,gamma=0.05)
gm2=GlobalModel(R.reactions1,gamma=0.1)
gm3=GlobalModel(R.reactions1,gamma=0.15)

pmin,pmax=1e5,3e6
nmin,nmax=1e14,8e14
Nn,Np=6,6
nn1,pp1,nH21,nH1,n11,n21,n31,ne1,e1=gm1.Find_solution_2D_sweep(pmin,pmax,nmin,nmax,Np,Nn)
nn2,pp2,nH22,nH2,n12,n22,n32,ne2,e2=gm2.Find_solution_2D_sweep(pmin,pmax,nmin,nmax,Np,Nn)
nn3,pp3,nH23,nH3,n13,n23,n33,ne3,e3=gm3.Find_solution_2D_sweep(pmin,pmax,nmin,nmax,Np,Nn)
N_mayoritario1,limites1=zonas(n11,n21,n31)
N_mayoritario2,limites2=zonas(n12,n22,n32)
N_mayoritario3,limites3=zonas(n13,n23,n33)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f7745e296b8f> in <module>
#       9 nn2,pp2,nH22,nH2,n12,n22,n32,ne2,e2=gm2.Find_solution_2D_sweep(pmin,pmax,nmin,nmax,Np,Nn)
#      10 nn3,pp3,nH23,nH3,n13,n23,n33,ne3,e3=gm3.Find_solution_2D_sweep(pmin,pmax,nmin,nmax,Np,Nn)
# ---> 11 N_mayoritario1,limites1=zonas(n11,n21,n31)
#      12 N_mayoritario2,limites2=zonas(n12,n22,n32)
#      13 N_mayoritario3,limites3=zonas(n13,n23,n33)
#
# NameError: name 'zonas' is not defined

# %%
# %matplotlib widget
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
mpl.rcParams['legend.fontsize'] = 10



#Species
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(nn1,pp1,nH1,s=2,alpha=0.5,label='H')
ax.scatter(nn3,pp2,nH2,s=2,alpha=0.5,label='H')
ax.scatter(nn3,pp3,nH3,s=2,alpha=0.5,label='H')
plt.xlabel('$n_0$ (cm$^{-3}$)')
plt.ylabel('$P_\mu$ (W/m$^{-3}$)')
ax.legend()
plt.tight_layout()

#T_e
mpl.rcParams['legend.fontsize'] = 10
fig = plt.figure(figsize=(6,5))
ax = fig.gca(projection='3d')
ax.scatter(nn1,pp1,e1,alpha=0.5,s=2,label='$T_e$ (eV)')
ax.scatter(nn2,pp2,e2,alpha=0.5,s=2,label='$T_e$ (eV)')
ax.scatter(nn3,pp3,e3,alpha=0.5,s=2,label='$T_e$ (eV)')
plt.xlabel('$n_0$ (cm$^{-3}$)')
plt.ylabel('$P_\mu$ (W/m$^{3}$)')
plt.tight_layout()
plt.legend()
plt.savefig('Figures/Gamma_sensibility_Te.pdf')

#n_e
mpl.rcParams['legend.fontsize'] = 10
fig = plt.figure(figsize=(6,5))
ax = fig.gca(projection='3d')
ax.scatter(nn1,pp1,ne1,alpha=0.5,s=2,label='$n_e$ (cm$^{-3}$)')
ax.scatter(nn2,pp2,ne2,alpha=0.5,s=2,label='$n_e$ (cm$^{-3}$)')
ax.scatter(nn3,pp3,ne3,alpha=0.5,s=2,label='$n_e$ (cm$^{-3}$)')
plt.xlabel('$n_0$ (cm$^{-3}$)')
plt.ylabel('$P_\mu$ (W/m$^{3}$)')
plt.tight_layout()
plt.legend()
plt.savefig('Figures/Gamma_sensibility_Ne.pdf')

#Dissociation degree
mpl.rcParams['legend.fontsize'] = 10
fig = plt.figure(figsize=(6,5))
ax = fig.gca(projection='3d')
ax.scatter(nn1,pp1,nH1/(nH1+2*nH21),alpha=0.5,s=2,label='Dissociation_degree')
ax.scatter(nn2,pp2,nH2/(nH2+2*nH22),alpha=0.5,s=2,label='Dissociation_degree')
ax.scatter(nn3,pp3,nH3/(nH3+2*nH23),alpha=0.5,s=2,label='Dissociation_degree')
plt.xlabel('$n_0$ (cm$^{-3}$)')
plt.ylabel('$P_\mu$ (W/m$^{-3}$)')
ax.legend()
plt.tight_layout()
plt.savefig('Figures/Gamma_sensibility_dissociation.pdf')


plt.figure(figsize=(8,4))
plt.scatter(nn1.flatten(),pp1.flatten(),c=limites1.flatten().T)
plt.scatter(nn2.flatten(),pp2.flatten(),c=limites2.flatten().T)
plt.scatter(nn3.flatten(),pp3.flatten(),c=limites3.flatten().T)
plt.xlim([nmin,nmax])
plt.ylim([pmin,pmax])
plt.xlabel('$n_0$ (cm$^{-3}$)')
plt.ylabel('$P_\mu$ (W/m$^{-3}$)')
plt.savefig('Figures/Predominant_map.pdf')

# %% [markdown]
# Sensibilidad a Aeff_V

# %%
gm1=GlobalModel(R.reactions,Aeff_V=0.07)
gm2=GlobalModel(R.reactions,Aeff_V=0.1)
gm3=GlobalModel(R.reactions,Aeff_V=0.13)

pmin,pmax=1e5,3e6
nmin,nmax=1e14,8e14
Nn,Np=10,10
nn1,pp1,nH21,nH1,n11,n21,n31,ne1,e1=gm1.Find_solution_2D_sweep(pmin,pmax,nmin,nmax,Np,Nn)
nn2,pp2,nH22,nH2,n12,n22,n32,ne2,e2=gm2.Find_solution_2D_sweep(pmin,pmax,nmin,nmax,Np,Nn)
nn3,pp3,nH23,nH3,n13,n23,n33,ne3,e3=gm3.Find_solution_2D_sweep(pmin,pmax,nmin,nmax,Np,Nn)
N_mayoritario1,limites1=zonas(n11,n21,n31)
N_mayoritario2,limites2=zonas(n12,n22,n32)
N_mayoritario3,limites3=zonas(n13,n23,n33)

# %%
# %matplotlib widget
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
mpl.rcParams['legend.fontsize'] = 10



#Species
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(nn1,pp1,nH1,s=2,alpha=0.5,label='H')
ax.scatter(nn3,pp2,nH2,s=2,alpha=0.5,label='H')
ax.scatter(nn3,pp3,nH3,s=2,alpha=0.5,label='H')
plt.xlabel('$n_0$ (cm$^{-3}$)')
plt.ylabel('$P_\mu$ (W/m$^{-3}$)')
ax.legend()
plt.tight_layout()

#T_e
mpl.rcParams['legend.fontsize'] = 10
fig = plt.figure(figsize=(6,5))
ax = fig.gca(projection='3d')
ax.scatter(nn1,pp1,e1,alpha=0.5,s=2,label='$T_e$ (eV)')
ax.scatter(nn2,pp2,e2,alpha=0.5,s=2,label='$T_e$ (eV)')
ax.scatter(nn3,pp3,e3,alpha=0.5,s=2,label='$T_e$ (eV)')
plt.xlabel('$n_0$ (cm$^{-3}$)')
plt.ylabel('$P_\mu$ (W/m$^{3}$)')
plt.tight_layout()
plt.legend()
plt.savefig('Figures/Aeff_V_sensibility_Te.pdf')

#n_e
mpl.rcParams['legend.fontsize'] = 10
fig = plt.figure(figsize=(6,5))
ax = fig.gca(projection='3d')
ax.scatter(nn1,pp1,ne1,alpha=0.5,s=2,label='$n_e$ (cm$^{-3}$)')
ax.scatter(nn2,pp2,ne2,alpha=0.5,s=2,label='$n_e$ (cm$^{-3}$)')
ax.scatter(nn3,pp3,ne3,alpha=0.5,s=2,label='$n_e$ (cm$^{-3}$)')
plt.xlabel('$n_0$ (cm$^{-3}$)')
plt.ylabel('$P_\mu$ (W/m$^{3}$)')
plt.tight_layout()
plt.legend()
plt.savefig('Figures/Aeff_V_sensibility_Ne.pdf')

#Dissociation degree
mpl.rcParams['legend.fontsize'] = 10
fig = plt.figure(figsize=(6,5))
ax = fig.gca(projection='3d')
ax.scatter(nn1,pp1,nH1/(nH1+2*nH21),alpha=0.5,s=2,label='Dissociation_degree')
ax.scatter(nn2,pp2,nH2/(nH2+2*nH22),alpha=0.5,s=2,label='Dissociation_degree')
ax.scatter(nn3,pp3,nH3/(nH3+2*nH23),alpha=0.5,s=2,label='Dissociation_degree')
plt.xlabel('$n_0$ (cm$^{-3}$)')
plt.ylabel('$P_\mu$ (W/m$^{-3}$)')
ax.legend()
plt.tight_layout()
plt.savefig('Figures/Aeff_V_sensibility_dissociation.pdf')


plt.figure(figsize=(8,4))
plt.scatter(nn1.flatten(),pp1.flatten(),c=limites1.flatten().T)
plt.scatter(nn2.flatten(),pp2.flatten(),c=limites2.flatten().T)
plt.scatter(nn3.flatten(),pp3.flatten(),c=limites3.flatten().T)
plt.xlim([nmin,nmax])
plt.ylim([pmin,pmax])
plt.xlabel('$n_0$ (cm$^{-3}$)')
plt.ylabel('$P_\mu$ (W/m$^{-3}$)')
plt.savefig('Figures/Aeff_V_sensibility_limits.pdf')
