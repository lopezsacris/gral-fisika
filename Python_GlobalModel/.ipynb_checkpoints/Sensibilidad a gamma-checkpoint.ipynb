# %%
from GeneralGlobalModel_Class import GlobalModel
import Reactions_H as R
import matplotlib.pyplot as plt
import numpy as np
me=9.11e-31
mp=1.67e-27
q=1.6e-19
reactions=R.reactions1
gm1=GlobalModel(reactions,[2*mp,0],gamma=0.03)
gm2=GlobalModel(reactions,[2*mp,0],gamma=0.1)
gm3=GlobalModel(reactions,[2*mp,0],gamma=0.3)

# %%
nmin,nmax=3e13,1e15
pmin,pmax=1e5,1e7
N=30
p0=2e6
n0=5e14
'''
_______________________________________________________________________
'''
fig,ax=plt.subplots(1,2,figsize=(10,3))
nH2,[ne,nH,n1,n2,n3,e]=gm1.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,n1,label='$\gamma$={}'.format(gm1.gamma))
nH2,[ne,nH,n1,n2,n3,e]=gm2.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,n1,label='$\gamma$={}'.format(gm2.gamma))
nH2,[ne,nH,n1,n2,n3,e]=gm3.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,n1,label='$\gamma$={}'.format(gm3.gamma))
p,[ne,nH,n1,n2,n3,e]=gm1.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,n1,label='$\gamma$={}'.format(gm1.gamma))
p,[ne,nH,n1,n2,n3,e]=gm2.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,n1,label='$\gamma$={}'.format(gm2.gamma))
p,[ne,nH,n1,n2,n3,e]=gm3.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,n1,label='$\gamma$={}'.format(gm3.gamma))

ax[0].set_ylabel('$T_e$ (eV)')
ax[0].set_xlabel('$n_0$ (cm$^{-3}$)')
ax[1].set_ylabel('$T_e$ (eV)')
ax[1].set_xlabel('$P_\mu$ (W/m$^{3}$)')
ax[0].set_xscale('log')
ax[1].set_xscale('log')
ax[0].set_yscale('log')
ax[1].set_yscale('log')
ax[0].legend()
ax[1].legend()
plt.tight_layout()
plt.savefig('Figures\Sensibility_gamma_h+.pdf')

# %%
nmin,nmax=3e13,1e15
pmin,pmax=1e5,1e7
N=30
p0=2e6
n0=5e14
'''
_______________________________________________________________________
'''
fig,ax=plt.subplots(1,2,figsize=(10,3))
nH2,[ne,nH,n1,n2,n3,e]=gm1.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,n2,label='$\gamma$={}'.format(gm1.gamma))
nH2,[ne,nH,n1,n2,n3,e]=gm2.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,n2,label='$\gamma$={}'.format(gm2.gamma))
nH2,[ne,nH,n1,n2,n3,e]=gm3.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,n2,label='$\gamma$={}'.format(gm3.gamma))
p,[ne,nH,n1,n2,n3,e]=gm1.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,n2,label='$\gamma$={}'.format(gm1.gamma))
p,[ne,nH,n1,n2,n3,e]=gm2.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,n2,label='$\gamma$={}'.format(gm2.gamma))
p,[ne,nH,n1,n2,n3,e]=gm3.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,n2,label='$\gamma$={}'.format(gm3.gamma))

ax[0].set_ylabel('$T_e$ (eV)')
ax[0].set_xlabel('$n_0$ (cm$^{-3}$)')
ax[1].set_ylabel('$T_e$ (eV)')
ax[1].set_xlabel('$P_\mu$ (W/m$^{3}$)')
ax[0].set_xscale('log')
ax[1].set_xscale('log')
ax[0].set_yscale('log')
ax[1].set_yscale('log')
ax[0].legend()
ax[1].legend()
plt.tight_layout()
plt.savefig('Figures\Sensibility_gamma_h2+.pdf')

# %%
nmin,nmax=3e13,1e15
pmin,pmax=1e5,1e7
N=30
p0=2e6
n0=5e14
'''
_______________________________________________________________________
'''
fig,ax=plt.subplots(1,2,figsize=(10,3))
nH2,[ne,nH,n1,n2,n3,e]=gm1.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,n3,label='$\gamma$={}'.format(gm1.gamma))
nH2,[ne,nH,n1,n2,n3,e]=gm2.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,n3,label='$\gamma$={}'.format(gm2.gamma))
nH2,[ne,nH,n1,n2,n3,e]=gm3.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,n3,label='$\gamma$={}'.format(gm3.gamma))
p,[ne,nH,n1,n2,n3,e]=gm1.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,n3,label='$\gamma$={}'.format(gm1.gamma))
p,[ne,nH,n1,n2,n3,e]=gm2.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,n3,label='$\gamma$={}'.format(gm2.gamma))
p,[ne,nH,n1,n2,n3,e]=gm3.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,n3,label='$\gamma$={}'.format(gm3.gamma))

ax[0].set_ylabel('$T_e$ (eV)')
ax[0].set_xlabel('$n_0$ (cm$^{-3}$)')
ax[1].set_ylabel('$T_e$ (eV)')
ax[1].set_xlabel('$P_\mu$ (W/m$^{3}$)')
ax[0].set_xscale('log')
ax[1].set_xscale('log')
ax[0].set_yscale('log')
ax[1].set_yscale('log')
ax[0].legend()
ax[1].legend()
plt.tight_layout()
plt.savefig('Figures\Sensibility_gamma_h3+.pdf')

# %%
'''No he definido esta función dentro de la clase GlobalModel, por que necesita
mucho tiempo en calcular la solución 2D. Por eso, calculo el resultado
con gm.Find_solution_2D_sweep y con la función Zonas() represento los mayoritarios utilizando la
solución anterior'''
def zonas(n1array,n2array,n3array):
    N_mayoritario=np.empty((n1array.shape[0],n1array.shape[1]))
    N_mayoritario[:]=np.nan
    limites=np.empty((n1array.shape[0],n1array.shape[1]))
    limites[:]=np.nan
    for i in range (n1array.shape[0]):
        for j in range (n1array.shape[1]):
            if (n1array[i,j]>n2array[i,j])&(n1array[i,j]>n3array[i,j]):
                N_mayoritario[i,j]=1
            if (n2array[i,j]>n1array[i,j])&(n2array[i,j]>n3array[i,j]):
                N_mayoritario[i,j]=2
            if (n3array[i,j]>n2array[i,j])&(n3array[i,j]>n1array[i,j]):
                N_mayoritario[i,j]=3
    for i in range(N_mayoritario.shape[0]-1):
        for j in range(N_mayoritario.shape[1]-1):
            if (N_mayoritario[i,j]!=N_mayoritario[i+1,j])|(N_mayoritario[i,j]!=N_mayoritario[i,j+1]):
                limites[i,j]=1
    return [N_mayoritario,limites]

pmin,pmax=1e5,6e6
nmin,nmax=3e13,7e15
Nn,Np=80,80
nn,pp,[ne,nH,n1,n2,n3,e]=gm1.Find_solution_2D_sweep(pmin,pmax,nmin,nmax,Np,Nn,scale='log')
N_mayoritario1,limites1=zonas(n1,n2,n3)
nn,pp,[ne,nH,n1,n2,n3,e]=gm2.Find_solution_2D_sweep(pmin,pmax,nmin,nmax,Np,Nn,scale='log')
N_mayoritario2,limites2=zonas(n1,n2,n3)
nn,pp,[ne,nH,n1,n2,n3,e]=gm3.Find_solution_2D_sweep(pmin,pmax,nmin,nmax,Np,Nn,scale='log')
N_mayoritario3,limites3=zonas(n1,n2,n3)

# %%
plt.figure(figsize=(8,4))
plt.scatter(nn.flatten(),pp.flatten(),c=limites1.flatten().T,marker='x',label='$\gamma$={}'.format(gm1.gamma))
plt.scatter(nn.flatten(),pp.flatten(),c=limites2.flatten().T,marker='+',label='$\gamma$={}'.format(gm2.gamma))
plt.scatter(nn.flatten(),pp.flatten(),c=limites3.flatten().T,marker='.',label='$\gamma$={}'.format(gm3.gamma))
plt.xlim([nmin,nmax])
plt.ylim([pmin,pmax])
plt.xscale('log')
plt.yscale('log')
plt.xlabel('$n_0$ (cm$^{-3}$)')
plt.ylabel('$P_\mu$ (W/m$^{-3}$)')
plt.savefig('sensibilidad_gamma_predominance')
