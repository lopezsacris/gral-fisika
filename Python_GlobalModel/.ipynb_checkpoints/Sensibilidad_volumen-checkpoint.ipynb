# %%
from GeneralGlobalModel_Class import GlobalModel
import Reactions_H as R
import matplotlib.pyplot as plt
import numpy as np
me=9.11e-31
mp=1.67e-27
q=1.6e-19
reactions=R.reactions1
gm1=GlobalModel(reactions,[2*mp,0],f=1)
gm2=GlobalModel(reactions,[2*mp,0],f=0.5)
gm3=GlobalModel(reactions,[2*mp,0],f=0.1)

# %%
nmin,nmax=3e13,4.5e14
pmin,pmax=1e5,1e7
N=30
p0=1e6
n0=1e14
'''
_______________________________________________________________________
'''
fig,ax=plt.subplots(1,2,figsize=(8,2.7))
nH2,[ne,nH,n1,n2,n3,e]=gm1.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,e,label='$f$={}'.format(gm1.f),c='black',linestyle='-')
nH2,[ne,nH,n1,n2,n3,e]=gm2.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,e,label='$f$={}'.format(gm2.f),c='black',linestyle='--')
nH2,[ne,nH,n1,n2,n3,e]=gm3.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,e,label='$f$={}'.format(gm3.f),c='black',linestyle='-.')
p,[ne,nH,n1,n2,n3,e]=gm1.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,e,label='$f$={}'.format(gm1.f),c='black',linestyle='-')
p,[ne,nH,n1,n2,n3,e]=gm2.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,e,label='$f$={}'.format(gm2.f),c='black',linestyle='--')
p,[ne,nH,n1,n2,n3,e]=gm3.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,e,label='$f$={}'.format(gm3.f),c='black',linestyle='-.')

ax[0].set_ylabel('$T_e$ (eV)')
ax[0].set_xlabel('$n_0$ (cm$^{-3}$)')
ax[1].set_ylabel('$T_e$ (eV)')
ax[1].set_xlabel('$P_\mu$ (W/m$^{3}$)')
ax[0].set_xscale('log')
ax[1].set_xscale('log')
ax[0].set_yscale('log')
ax[1].set_yscale('log')
ax[0].legend()
ax[1].legend()
plt.tight_layout()
plt.savefig('Figures\Sensibility_volumen_Te.pdf')

# %%
nmin,nmax=3e13,4.5e14
pmin,pmax=1e5,1e7
N=10
p0=2e6
n0=5e14
'''
_______________________________________________________________________
'''
fig,ax=plt.subplots(1,2,figsize=(8,2.7))
nH2,[ne,nH,n1,n2,n3,e]=gm1.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,ne,label='$f$={}'.format(gm1.f),color='red')
nH2,[ne,nH,n1,n2,n3,e]=gm2.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,ne,label='$f$={}'.format(gm2.f),color='salmon')
nH2,[ne,nH,n1,n2,n3,e]=gm3.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,ne,label='$f$={}'.format(gm3.f),color='lightsalmon')
p,[ne,nH,n1,n2,n3,e]=gm1.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,ne,label='$f$={}'.format(gm1.f),color='red')
p,[ne,nH,n1,n2,n3,e]=gm2.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,ne,label='$f$={}'.format(gm2.f),color='salmon')
p,[ne,nH,n1,n2,n3,e]=gm3.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,ne,label='$f$={}'.format(gm3.f),color='lightsalmon')

ax[0].set_ylabel('$n$ (cm$^{-3}$)')
ax[0].set_xlabel('$n_0$ (cm$^{-3}$)')
ax[1].set_ylabel('$n$ (cm$^{-3}$)')
ax[1].set_xlabel('$P_\mu$ (W/m$^{3}$)')
ax[0].set_xscale('log')
ax[1].set_xscale('log')
ax[0].set_yscale('log')
ax[1].set_yscale('log')
ax[0].legend()
ax[1].legend()
plt.tight_layout()
#plt.savefig('Figures\Sensibility_volumen_h+.pdf')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
nmin,nmax=3e13,4.5e14
pmin,pmax=1e5,1e7
N=30
p0=1e6
n0=1e14
'''
_______________________________________________________________________
'''
fig,ax=plt.subplots(1,2,figsize=(8,2.7))
nH2,[ne,nH,n1,n2,n3,e]=gm1.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,n1,label='$f$={}'.format(gm1.f),color='blue',linestyle='-')
nH2,[ne,nH,n1,n2,n3,e]=gm2.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,n1,label='$f$={}'.format(gm2.f),color='blue',linestyle='--')
nH2,[ne,nH,n1,n2,n3,e]=gm3.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,n1,label='$f$={}'.format(gm3.f),color='blue',linestyle='-.')
p,[ne,nH,n1,n2,n3,e]=gm1.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,n1,label='$f$={}'.format(gm1.f),color='blue',linestyle='-')
p,[ne,nH,n1,n2,n3,e]=gm2.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,n1,label='$f$={}'.format(gm2.f),color='blue',linestyle='--')
p,[ne,nH,n1,n2,n3,e]=gm3.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,n1,label='$f$={}'.format(gm3.f),color='blue',linestyle='-.')

ax[0].set_ylabel('$n$ (cm$^{-3}$)')
ax[0].set_xlabel('$n_0$ (cm$^{-3}$)')
ax[1].set_ylabel('$n$ (cm$^{-3}$)')
ax[1].set_xlabel('$P_\mu$ (W/m$^{3}$)')
ax[0].set_xscale('log')
ax[1].set_xscale('log')
ax[0].set_yscale('log')
ax[1].set_yscale('log')
ax[0].legend()
ax[1].legend()
plt.tight_layout()
plt.savefig('Figures\Sensibility_volumen_h+.pdf')

# %%
nmin,nmax=3e13,4.5e14
pmin,pmax=1e5,1e7
N=30
p0=1e6
n0=1e14
'''
_______________________________________________________________________
'''
fig,ax=plt.subplots(1,2,figsize=(8,2.7))
nH2,[ne,nH,n1,n2,n3,e]=gm1.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,n2,label='$f$={}'.format(gm1.f),color='red',linestyle='-')
nH2,[ne,nH,n1,n2,n3,e]=gm2.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,n2,label='$f$={}'.format(gm2.f),color='red',linestyle='--')
nH2,[ne,nH,n1,n2,n3,e]=gm3.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,n2,label='$f$={}'.format(gm3.f),color='red',linestyle='-.')
p,[ne,nH,n1,n2,n3,e]=gm1.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,n2,label='$f$={}'.format(gm1.f),color='red',linestyle='-')
p,[ne,nH,n1,n2,n3,e]=gm2.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,n2,label='$f$={}'.format(gm2.f),color='red',linestyle='--')
p,[ne,nH,n1,n2,n3,e]=gm3.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,n2,label='$f$={}'.format(gm3.f),color='red',linestyle='-.')

ax[0].set_ylabel('$n$ (cm$^{-3}$)')
ax[0].set_xlabel('$n_0$ (cm$^{-3}$)')
ax[1].set_ylabel('$n$ (cm$^{-3}$)')
ax[1].set_xlabel('$P_\mu$ (W/m$^{3}$)')
ax[0].set_xscale('log')
ax[1].set_xscale('log')
ax[0].set_yscale('log')
ax[1].set_yscale('log')
ax[0].legend()
ax[1].legend()
plt.tight_layout()
plt.savefig('Figures\Sensibility_volumen_h2+.pdf')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
nmin,nmax=3e13,4.5e14
pmin,pmax=1e5,1e7
N=30
p0=1e6
n0=1e14
'''
_______________________________________________________________________
'''
fig,ax=plt.subplots(1,2,figsize=(8,2.7))
nH2,[ne,nH,n1,n2,n3,e]=gm1.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,n3,label='$f$={}'.format(gm1.f),color='green',linestyle='-')
nH2,[ne,nH,n1,n2,n3,e]=gm2.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,n3,label='$f$={}'.format(gm2.f),color='green',linestyle='--')
nH2,[ne,nH,n1,n2,n3,e]=gm3.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,n3,label='$f$={}'.format(gm3.f),color='green',linestyle='-.')
p,[ne,nH,n1,n2,n3,e]=gm1.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,n3,label='$f$={}'.format(gm1.f),color='green',linestyle='-')
p,[ne,nH,n1,n2,n3,e]=gm2.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,n3,label='$f$={}'.format(gm2.f),color='green',linestyle='--')
p,[ne,nH,n1,n2,n3,e]=gm3.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,n3,label='$f$={}'.format(gm3.f),color='green',linestyle='-.')

ax[0].set_ylabel('$n$ (cm$^{-3}$)')
ax[0].set_xlabel('$n_0$ (cm$^{-3}$)')
ax[1].set_ylabel('$n$ (cm$^{-3}$)')
ax[1].set_xlabel('$P_\mu$ (W/m$^{3}$)')
ax[0].set_xscale('log')
ax[1].set_xscale('log')
ax[0].set_yscale('log')
ax[1].set_yscale('log')
ax[0].legend()
ax[1].legend()
plt.tight_layout()
plt.savefig('Figures\Sensibility_volumen_h3+.pdf')

# %%
'''No he definido esta función dentro de la clase GlobalModel, por que necesita
mucho tiempo en calcular la solución 2D. Por eso, calculo el resultado
con gm.Find_solution_2D_sweep y con la función Zonas() represento los mayoritarios utilizando la
solución anterior'''
def zonas(n1array,n2array,n3array):
    N_mayoritario=np.empty((n1array.shape[0],n1array.shape[1]))
    N_mayoritario[:]=np.nan
    limites=np.empty((n1array.shape[0],n1array.shape[1]))
    limites[:]=np.nan
    for i in range (n1array.shape[0]):
        for j in range (n1array.shape[1]):
            if (n1array[i,j]>n2array[i,j])&(n1array[i,j]>n3array[i,j]):
                N_mayoritario[i,j]=1
            if (n2array[i,j]>n1array[i,j])&(n2array[i,j]>n3array[i,j]):
                N_mayoritario[i,j]=2
            if (n3array[i,j]>n2array[i,j])&(n3array[i,j]>n1array[i,j]):
                N_mayoritario[i,j]=3
    for i in range(N_mayoritario.shape[0]-1):
        for j in range(N_mayoritario.shape[1]-1):
            if (N_mayoritario[i,j]!=N_mayoritario[i+1,j])|(N_mayoritario[i,j]!=N_mayoritario[i,j+1]):
                limites[i,j]=1
    return [N_mayoritario,limites]

def to_vector(nn,pp,limites):
    I,J=nn.shape
    n_lims,p_lims=[],[]
    for i in range (I):
        for j in range (J):
            n=nn[i,j]
            p=pp[i,j]
            if limites[i,j]==1:
                n_lims.append(n)
                p_lims.append(p)
    return (n_lims,p_lims)

pmin,pmax=1e5,6e6
nmin,nmax=4e13,4.5e14
Nn,Np=100,100
nn,pp,[ne1,nH1,n11,n21,n31,e1]=gm1.Find_solution_2D_sweep(pmin,pmax,nmin,nmax,Np,Nn,scale='log')
N_mayoritario1,limites1=zonas(n11,n21,n31)
nn,pp,[ne2,nH2,n12,n22,n32,e2]=gm2.Find_solution_2D_sweep(pmin,pmax,nmin,nmax,Np,Nn,scale='log')
N_mayoritario2,limites2=zonas(n12,n22,n32)
nn,pp,[ne3,nH3,n13,n23,n33,e3]=gm3.Find_solution_2D_sweep(pmin,pmax,nmin,nmax,Np,Nn,scale='log')
N_mayoritario3,limites3=zonas(n13,n23,n33)

# %%
# %matplotlib widget
plt.figure(figsize=(8,4))
plt.scatter((nn+nH).flatten(),pp.flatten(),c=limites1.flatten().T,marker='x',label='$\gamma$={}'.format(gm1.gamma))
plt.scatter((nn+nH).flatten(),pp.flatten(),c=limites2.flatten().T,marker='+',label='$\gamma$={}'.format(gm2.gamma))
plt.scatter((nn+nH).flatten(),pp.flatten(),c=limites3.flatten().T,marker='.',label='$\gamma$={}'.format(gm3.gamma))
plt.xlim([4e13,nmax])
plt.ylim([pmin,4.85e6])
plt.xscale('log')
plt.yscale('log')
plt.xlabel('$n_0$ (cm$^{-3}$)')
plt.ylabel('$P_\mu$ (W/m$^{-3}$)')
plt.savefig('Figures/sensibilidad_volumen_predominance.pdf')

# %%
def style (i):
    color_list=['tab:blue','tab:orange','tab:green','tab:red','tab:purple','black']
    marker_list=['-','--','-.',':']
    k,j=np.divmod(i,len(color_list))
    return color_list[j],marker_list[k]

# %%
n0=3e14
pmin,pmax=3e5,3e6
p0=3e6
nmin,nmax=5e13,6e14
N=10
specie=[2*mp,1]
'''
_________________________________________________________________________________
'''
# %matplotlib inline
fig,ax=plt.subplots(1,3,figsize=(10,5))
ps,names0,values0=gm1.Contributions_p_sweep(specie,n0,pmin,pmax,N,'log')
for i in range (values0[0,:].size):
    color,marker=style(i)
    ax[0].plot(ps,abs(values0[:,i]),color=color,linestyle=marker,label=names0[i])
ps,names0,values0=gm2.Contributions_p_sweep(specie,n0,pmin,pmax,N,'log')
for i in range (values0[0,:].size):
    color,marker=style(i)
    ax[1].plot(ps,abs(values0[:,i]),color=color,linestyle=marker,label=names0[i])
ps,names0,values0=gm3.Contributions_p_sweep(specie,n0,pmin,pmax,N,'log')
for i in range (values0[0,:].size):
    color,marker=style(i)
    ax[2].plot(ps,abs(values0[:,i]),color=color,linestyle=marker,label=names0[i])

ax[0].set_xlabel('P$_\mu$(W/m$^3$)')
ax[1].set_xlabel('P$_\mu$(W/m$^3$)')
ax[2].set_xlabel('P$_\mu$(W/m$^3$)')
ax[0].set_ylabel('$n_in_j$|<$\sigma$v>|')
ax[0].set_yscale('log')
ax[1].set_yscale('log')
ax[2].set_yscale('log')
ax[0].set_xscale('log')
ax[1].set_xscale('log')
ax[2].set_xscale('log')
ax[2].legend(bbox_to_anchor=(1.04,1), loc="upper left")
#fig.suptitle('Reactions involving H', fontsize=16)
plt.tight_layout()
#plt.savefig('Figures/Contributions_h.pdf')

# %%
n0=3e14
pmin,pmax=3e5,3e6
p0=3e6
nmin,nmax=5e13,6e14
N=10
specie=[2*mp,1]
'''
_________________________________________________________________________________
'''
# %matplotlib inline
fig,ax=plt.subplots(1,1,figsize=(10,5))
ps,names0,values0=gm1.Contributions_p_sweep(specie,n0,pmin,pmax,N,'log')
for i in range (values0[0,:].size):
    color,marker=style(i)
    ax.plot(ps,abs(values0[:,i]),color=color,linestyle=marker,label=names0[i])
ps,names0,values0=gm2.Contributions_p_sweep(specie,n0,pmin,pmax,N,'log')
for i in range (values0[0,:].size):
    color,marker=style(i)
    ax.plot(ps,abs(values0[:,i]),color=color,linestyle=marker,label=names0[i])
ps,names0,values0=gm3.Contributions_p_sweep(specie,n0,pmin,pmax,N,'log')
for i in range (values0[0,:].size):
    color,marker=style(i)
    ax.plot(ps,abs(values0[:,i]),color=color,linestyle=marker,label=names0[i])

ax.set_xlabel('P$_\mu$(W/m$^3$)')
ax.set_ylabel('$n_in_j$|<$\sigma$v>|')
ax.set_yscale('log')
ax.set_xscale('log')
ax.legend(bbox_to_anchor=(1.04,1), loc="upper left")
#fig.suptitle('Reactions involving H', fontsize=16)
plt.tight_layout()
#plt.savefig('Figures/Contributions_h.pdf')

# %%
from matplotlib.colors import Normalize
import matplotlib.cm as cm

plt.figure(figsize=(8,4))


ns,ps=to_vector(nn+nH1,pp,limites1)
plt.scatter(ns,ps,label='$f$={}'.format(gm1.f),marker='o',c='purple')
ns,ps=to_vector(nn+nH2,pp,limites2)
plt.scatter(ns,ps,label='$f$={}'.format(gm2.f),marker='o',c='plum')
ns,ps=to_vector(nn+nH3,pp,limites3)
plt.scatter(ns,ps,label='$f$={}'.format(gm3.f),marker='o',c='orange')
plt.xlim([6e13,nmax])
plt.ylim([pmin,4e6])
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.xlabel('$n_0$ (cm$^{-3}$)')
plt.ylabel('$P_\mu$ (W/m$^{3}$)')
plt.savefig('Figures\sensibilidad_volumen_predominance.pdf')

# %%
sol2 = gm2.Find_solution(1.1e6,1.1e14)
sol2[0]
# Out:
# array([8.84784033e+11, 2.96502597e+13, 3.19390240e+11, 2.72434285e+11,
#        2.92959508e+11, 5.60174319e+00])
