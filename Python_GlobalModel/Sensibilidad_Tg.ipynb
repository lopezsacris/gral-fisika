# %%
from GeneralGlobalModel_Class import GlobalModel
import Reactions_H as R
import matplotlib.pyplot as plt
import numpy as np
me=9.11e-31
mp=1.67e-27
q=1.6e-19
reactions=R.reactions1
gm1=GlobalModel(reactions,[2*mp,0],Tg=300)
gm2=GlobalModel(reactions,[2*mp,0],Tg=500)
gm3=GlobalModel(reactions,[2*mp,0],Tg=700)

# %%
nmin,nmax=3e13,4.5e14
pmin,pmax=1e5,1e7
N=30
p0=1e6
n0=3e14
'''
_______________________________________________________________________
'''
fig,ax=plt.subplots(1,2,figsize=(8,2.7))
nH2,[ne,nH,n1,n2,n3,e]=gm1.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,nH,label='$T_g$={} K'.format(gm1.Tg),color='black',linestyle='-')
nH2,[ne,nH,n1,n2,n3,e]=gm2.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,nH,label='$T_g$={} K'.format(gm2.Tg),color='black',linestyle='--')
nH2,[ne,nH,n1,n2,n3,e]=gm3.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,nH,label='$T_g$={} K'.format(gm3.Tg),color='black',linestyle='-.')
p,[ne,nH,n1,n2,n3,e]=gm1.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,nH,label='$T_g$={} K'.format(gm1.Tg),color='black',linestyle='-')
p,[ne,nH,n1,n2,n3,e]=gm2.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,nH,label='$T_g$={} K'.format(gm2.Tg),color='black',linestyle='--')
p,[ne,nH,n1,n2,n3,e]=gm3.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,nH,label='$T_g$={} K'.format(gm3.Tg),color='black',linestyle='-.')

ax[0].set_ylabel('$n$ (cm$^{-3}$)')
ax[0].set_xlabel('$n_0$ (cm$^{-3}$)')
ax[1].set_ylabel('$n$ (cm$^{-3}$)')
ax[1].set_xlabel('$P_\mu$ (W/m$^{3}$)')
ax[0].set_xscale('log')
ax[1].set_xscale('log')
ax[0].set_yscale('log')
ax[1].set_yscale('log')
ax[0].legend()
ax[1].legend()
plt.tight_layout()
plt.savefig('Figures\Sensibility_Tg_h.pdf')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
nmin,nmax=3e13,4.5e14
pmin,pmax=1e5,1e7
N=30
p0=1e6
n0=3e14
'''
_______________________________________________________________________
'''
fig,ax=plt.subplots(1,2,figsize=(8,2.7))
nH2,[ne,nH,n1,n2,n3,e]=gm1.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,n1,label='$T_g$={} K'.format(gm1.Tg),color='blue',linestyle='-')
nH2,[ne,nH,n1,n2,n3,e]=gm2.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,n1,label='$T_g$={} K'.format(gm2.Tg),color='blue',linestyle='--')
nH2,[ne,nH,n1,n2,n3,e]=gm3.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,n1,label='$T_g$={} K'.format(gm3.Tg),color='blue',linestyle='-.')
p,[ne,nH,n1,n2,n3,e]=gm1.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,n1,label='$T_g$={} K'.format(gm1.Tg),color='blue',linestyle='-')
p,[ne,nH,n1,n2,n3,e]=gm2.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,n1,label='$T_g$={} K'.format(gm2.Tg),color='blue',linestyle='--')
p,[ne,nH,n1,n2,n3,e]=gm3.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,n1,label='$T_g$={} K'.format(gm3.Tg),color='blue',linestyle='-.')

ax[0].set_ylabel('$n$ (cm$^{-3}$)')
ax[0].set_xlabel('$n_0$ (cm$^{-3}$)')
ax[1].set_ylabel('$n$ (cm$^{-3}$)')
ax[1].set_xlabel('$P_\mu$ (W/m$^{3}$)')
ax[0].set_xscale('log')
ax[1].set_xscale('log')
ax[0].set_yscale('log')
ax[1].set_yscale('log')
ax[0].legend()
ax[1].legend()
plt.tight_layout()
plt.savefig('Figures\Sensibility_Tg_h+.pdf')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
nmin,nmax=3e13,4.5e14
pmin,pmax=1e5,1e7
N=30
p0=1e6
n0=1e14
'''
_______________________________________________________________________
'''
fig,ax=plt.subplots(1,2,figsize=(8,2.7))
nH2,[ne,nH,n1,n2,n3,e]=gm1.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,n2,label='$T_g$={} K'.format(gm1.Tg),color='red',linestyle='-')
nH2,[ne,nH,n1,n2,n3,e]=gm2.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,n2,label='$T_g$={} K'.format(gm2.Tg),color='red',linestyle='--')
nH2,[ne,nH,n1,n2,n3,e]=gm3.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,n2,label='$T_g$={} K'.format(gm3.Tg),color='red',linestyle='-.')
p,[ne,nH,n1,n2,n3,e]=gm1.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,n2,label='$T_g$={} K'.format(gm1.Tg),color='red',linestyle='-')
p,[ne,nH,n1,n2,n3,e]=gm2.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,n2,label='$T_g$={} K'.format(gm2.Tg),color='red',linestyle='--')
p,[ne,nH,n1,n2,n3,e]=gm3.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,n2,label='$T_g$={} K'.format(gm3.Tg),color='red',linestyle='-.')

ax[0].set_ylabel('$n$ (cm$^{-3}$)')
ax[0].set_xlabel('$n_0$ (cm$^{-3}$)')
ax[1].set_ylabel('$n$ (cm$^{-3}$)')
ax[1].set_xlabel('$P_\mu$ (W/m$^{3}$)')
ax[0].set_xscale('log')
ax[1].set_xscale('log')
ax[0].set_yscale('log')
ax[1].set_yscale('log')
ax[0].legend()
ax[1].legend()
plt.tight_layout()
plt.savefig('Figures\Sensibility_Tg_h2+.pdf')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
nmin,nmax=3e13,4.5e14
pmin,pmax=1e5,1e7
N=30
p0=3e6
n0=1e14
'''
_______________________________________________________________________
'''
fig,ax=plt.subplots(1,2,figsize=(8,2.7))
nH2,[ne,nH,n1,n2,n3,e]=gm1.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,n3,label='$T_g$={} K'.format(gm1.Tg),color='green',linestyle='-')
nH2,[ne,nH,n1,n2,n3,e]=gm2.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,n3,label='$T_g$={} K'.format(gm2.Tg),color='green',linestyle='--')
nH2,[ne,nH,n1,n2,n3,e]=gm3.Find_solution_n_sweep(p0,nmin,nmax,N,'log')
ng=nH+nH2
ax[0].plot(ng,n3,label='$T_g$={} K'.format(gm3.Tg),color='green',linestyle='-.')
p,[ne,nH,n1,n2,n3,e]=gm1.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,n3,label='$T_g$={} K'.format(gm1.Tg),color='green',linestyle='-')
p,[ne,nH,n1,n2,n3,e]=gm2.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,n3,label='$T_g$={} K'.format(gm2.Tg),color='green',linestyle='--')
p,[ne,nH,n1,n2,n3,e]=gm3.Find_solution_p_sweep(n0,pmin,pmax,N,'log')
ax[1].plot(p,n3,label='$T_g$={} K'.format(gm3.Tg),color='green',linestyle='-.')

ax[0].set_ylabel('$n$ (cm$^{-3}$)')
ax[0].set_xlabel('$n_0$ (cm$^{-3}$)')
ax[1].set_ylabel('$n$ (cm$^{-3}$)')
ax[1].set_xlabel('$P_\mu$ (W/m$^{3}$)')
ax[0].set_xscale('log')
ax[1].set_xscale('log')
ax[0].set_yscale('log')
ax[1].set_yscale('log')
ax[0].legend()
ax[1].legend()
plt.tight_layout()
plt.savefig('Figures\Sensibility_Tg_h3+.pdf')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
'''No he definido esta función dentro de la clase GlobalModel, por que necesita
mucho tiempo en calcular la solución 2D. Por eso, calculo el resultado
con gm.Find_solution_2D_sweep y con la función Zonas() represento los mayoritarios utilizando la
solución anterior'''
def zonas(n1array,n2array,n3array):
    N_mayoritario=np.empty((n1array.shape[0],n1array.shape[1]))
    N_mayoritario[:]=np.nan
    limites=np.empty((n1array.shape[0],n1array.shape[1]))
    limites[:]=np.nan
    for i in range (n1array.shape[0]):
        for j in range (n1array.shape[1]):
            if (n1array[i,j]>n2array[i,j])&(n1array[i,j]>n3array[i,j]):
                N_mayoritario[i,j]=1
            if (n2array[i,j]>n1array[i,j])&(n2array[i,j]>n3array[i,j]):
                N_mayoritario[i,j]=2
            if (n3array[i,j]>n2array[i,j])&(n3array[i,j]>n1array[i,j]):
                N_mayoritario[i,j]=3
    for i in range(N_mayoritario.shape[0]-1):
        for j in range(N_mayoritario.shape[1]-1):
            if (N_mayoritario[i,j]!=N_mayoritario[i+1,j])|(N_mayoritario[i,j]!=N_mayoritario[i,j+1]):
                limites[i,j]=1
    return [N_mayoritario,limites]

def to_vector(nn,pp,limites):
    I,J=nn.shape
    n_lims,p_lims=[],[]
    for i in range (I):
        for j in range (J):
            n=nn[i,j]
            p=pp[i,j]
            if limites[i,j]==1:
                n_lims.append(n)
                p_lims.append(p)
    return (n_lims,p_lims)

pmin,pmax=1e5,6e6
nmin,nmax=4e13,4.5e14
Nn,Np=100,100
nn,pp,[ne1,nH1,n11,n21,n31,e1]=gm1.Find_solution_2D_sweep(pmin,pmax,nmin,nmax,Np,Nn,scale='log')
N_mayoritario1,limites1=zonas(n11,n21,n31)
nn,pp,[ne2,nH2,n12,n22,n32,e2]=gm2.Find_solution_2D_sweep(pmin,pmax,nmin,nmax,Np,Nn,scale='log')
N_mayoritario2,limites2=zonas(n12,n22,n32)
nn,pp,[ne3,nH3,n13,n23,n33,e3]=gm3.Find_solution_2D_sweep(pmin,pmax,nmin,nmax,Np,Nn,scale='log')
N_mayoritario3,limites3=zonas(n13,n23,n33)

# %%
# %matplotlib widget
plt.figure(figsize=(8,4))
plt.scatter((nn+nH).flatten(),pp.flatten(),c=limites1.flatten().T,marker='x',label='$T_i$={}'.format(gm1.Ti))
plt.scatter((nn+nH).flatten(),pp.flatten(),c=limites2.flatten().T,marker='+',label='$T_i$={}'.format(gm2.Ti))
plt.scatter((nn+nH).flatten(),pp.flatten(),c=limites3.flatten().T,marker='.',label='$T_i$={}'.format(gm3.Ti))
plt.xlim([5.5e13,nmax])
plt.ylim([pmin,2e6])
plt.xscale('log')
plt.yscale('log')
#plt.legend()
plt.xlabel('$n_0$ (cm$^{-3}$)')
plt.ylabel('$P_\mu$ (W/m$^{3}$)')
plt.savefig('Figures\sensibilidad_Tg_predominance.pdf')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26712/567294369.py in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'widget')
#       2 plt.figure(figsize=(8,4))
# ----> 3 plt.scatter((nn+nH).flatten(),pp.flatten(),c=limites1.flatten().T,marker='x',label='$T_i$={}'.format(gm1.Ti))
#       4 plt.scatter((nn+nH).flatten(),pp.flatten(),c=limites2.flatten().T,marker='+',label='$T_i$={}'.format(gm2.Ti))
#       5 plt.scatter((nn+nH).flatten(),pp.flatten(),c=limites3.flatten().T,marker='.',label='$T_i$={}'.format(gm3.Ti))
#
# ValueError: operands could not be broadcast together with shapes (100,100) (30,)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from matplotlib.colors import Normalize
import matplotlib.cm as cm

plt.figure(figsize=(8,4))


#ns,ps=to_vector(nn+nH1,pp,limites1)
#plt.scatter(ns,ps,label='$T_g$={} K'.format(gm1.Tg),marker='o',c='purple')
ns,ps=to_vector(nn+nH2,pp,limites2)
plt.scatter(ns,ps,label='$T_g$={} K'.format(gm2.Tg),marker='o',c='black')
#ns,ps=to_vector(nn+nH3,pp,limites3)
#plt.scatter(ns,ps,label='$T_g$={} K'.format(gm3.Tg),marker='o',c='orange')
plt.xlim([5.6e13,nmax])
plt.ylim([pmin,2e6])
plt.xscale('log')
plt.yscale('log')
#plt.legend()
plt.xlabel('$n_0$ (cm$^{-3}$)')
plt.ylabel('$P_\mu$ (W/m$^{3}$)')
plt.tight_layout()
plt.savefig('Presentacion\sensibilidad_predominance.png')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
