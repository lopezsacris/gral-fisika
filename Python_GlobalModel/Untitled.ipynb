# %%
from GlobalModel_Class import GlobalModel
import Reactions_He as R
import matplotlib.pyplot as plt
import numpy as np

# %%
reactions=R.reactions
gm2=GlobalModel(reactions)

# %%
gm2.volume_reactions
# Out:
# [['e+He=>2e+He+',
#   'ionization',
#   [[9.11e-31, -1, 1], [3.34e-27, 0, 1]],
#   [[9.11e-31, -1, 2], [3.34e-27, 1, 1]],
#   3.16,
#   <function Reactions_He.<lambda>(x)>],
#  ['e+He+=>2e+He2+',
#   'ionization',
#   [[9.11e-31, -1, 1], [3.34e-27, 1, 1]],
#   [[9.11e-31, -1, 2], [3.34e-27, 2, 1]],
#   7.94,
#   <function Reactions_He.<lambda>(x)>],
#  ['e+He=>e+He+*',
#   'excitation',
#   [[9.11e-31, -1, 1], [3.34e-27, 0, 1]],
#   [[9.11e-31, -1, 1], [3.34e-27, 0, 1]],
#   3.98,
#   <function Reactions_He.<lambda>(x)>]]

# %%
# %matplotlib inline
figure=plt.figure(figsize=(12,5))
elog=np.logspace(-0.5,3)
for i in range (len(reactions)):
    r=reactions[i]
    if r[1]!='surface':
        plt.plot(elog,r[5](elog),label=r[0])
plt.yscale('log')
plt.xscale('log')
plt.ylim(1e-11,1e-6)
plt.xlabel('T(eV)')
plt.ylabel('$<\sigma v>$ (cm$^{3}$/s)')
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.tight_layout()

# %%
n,nHe_p,nHe_2p,ne,e=gm2.Find_solution_n_sweep(5e6,5e13,1e15,30)
plt.plot(n,nHe_p,color='blue',label='He+')
plt.plot(n,nHe_2p,color='red',label='He2+')

plt.legend()
plt.ylabel('$n$ (cm$^{-3}$)')
plt.xlabel('$n_0$ (cm$^{-3}$)')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-74def48209cb> in <module>
# ----> 1 n,nHe_p,nHe_2p,ne,e=gm2.Find_solution_n_sweep(5e6,5e13,1e15,30)
#       2 plt.plot(n,nHe_p,color='blue',label='He+')
#       3 plt.plot(n,nHe_2p,color='red',label='He2+')
#       4
#       5 plt.legend()
#
# ~\Documents\LINAC7\TFM\Programak\Python_GlobalModel\GlobalModel_Class.py in Find_solution_n_sweep(self, p0, n0, n1, N)
#     326         n,n1,n2,n3,nH,e=[],[],[],[],[],[]
#     327         for ni in ns:
# --> 328             sol=self.Find_solution(p0,ni)
#     329             n=np.append(n,ni)
#     330             nH=np.append(nH,sol[0][1])
#
# ~\Documents\LINAC7\TFM\Programak\Python_GlobalModel\GlobalModel_Class.py in Find_solution(self, pwr, n)
#     304         e0=1
#     305         init=[1e12,1e14,1e12,1e12,1e12,e0]
# ...
